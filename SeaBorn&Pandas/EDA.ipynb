# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('d:\\item_details.csv')

# %%
#Eda process 
df['First Name'].fillna('not mentioned',inplace=True)

# %%
df['Gender'].fillna('not mentioned',inplace=True)

# %%
df['Senior Management'].count()

# %%
m=df['Senior Management'].mode().values[0]

# %%
import numpy as np
df['Senior Management']=df['Senior Management'].replace(np.nan,m)

# %%
df.isnull().sum()

# %%
df.dropna()

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df.isnull().sum()

# %%
df.shape

# %%
-univarient
-bivarient
-multi varient

# %%
df1=pd.read_csv('d:\\height_weight_eda.csv')

# %%
df1
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df1.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
sns.boxplot(x='Height',data=df1)
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(x='Weight',data=df1)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
df=pd.read_csv('d:\\housing.csv')

# %%
df
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0   5850.0         3      NaN      2.0      yes
# 1             2   38500.0   4000.0         2      1.0      1.0      yes
# 2             3   49500.0   3060.0         3      1.0      1.0      yes
# 3             4   60500.0      NaN         3      1.0      NaN      yes
# 4             5   61000.0   6360.0         2      NaN      1.0      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0   4800.0         3      2.0      4.0      yes
# 542         543   94000.0   6000.0         3      2.0      4.0      yes
# 543         544  103000.0   6000.0         3      2.0      4.0      yes
# 544         545  105000.0   6000.0         3      2.0      2.0      yes
# 545         546  105000.0   6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df
# Out:
#      Unnamed: 0     price lotsize  bedrooms  bathrms  stories driveway  \
# 1             2   38500.0  4000.0         2      1.0      1.0      yes
# 2             3   49500.0  3060.0         3      1.0      1.0      yes
# 5             6   66000.0  4160.0         3      1.0      1.0      yes
# 6             7   66000.0  3880.0         3      2.0      2.0      yes
# 7             8   69000.0  4160.0         3      1.0      3.0      yes
# ..          ...       ...     ...       ...      ...      ...      ...
# 541         542   91500.0  4800.0         3      2.0      4.0      yes
# 542         543   94000.0  6000.0         3      2.0      4.0      yes
# 543         544  103000.0  6000.0         3      2.0      4.0      yes
# 544         545  105000.0  6000.0         3      2.0      2.0      yes
# 545         546  105000.0  6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# 1        no       no    no    no         0       no
# ...

# %%
m=df['driveway'].mode().values[0]

# %%
m
# Out:
# 'yes'

# %%
df['driveway']=df['driveway'].replace(np.nan,m)

# %%
df
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0   5850.0         3      NaN      2.0      yes
# 1             2   38500.0   4000.0         2      1.0      1.0      yes
# 2             3   49500.0   3060.0         3      1.0      1.0      yes
# 3             4   60500.0      NaN         3      1.0      NaN      yes
# 4             5   61000.0   6360.0         2      NaN      1.0      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0   4800.0         3      2.0      4.0      yes
# 542         543   94000.0   6000.0         3      2.0      4.0      yes
# 543         544  103000.0   6000.0         3      2.0      4.0      yes
# 544         545  105000.0   6000.0         3      2.0      2.0      yes
# 545         546  105000.0   6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       0
# bedrooms      0
# bathrms       0
# stories       0
# driveway      0
# recroom       0
# fullbase      0
# gashw         0
# airco         0
# garagepl      0
# prefarea      0
# dtype: int64

# %%
df.dropna()
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 1             2   38500.0   4000.0         2      1.0      1.0      yes
# 2             3   49500.0   3060.0         3      1.0      1.0      yes
# 5             6   66000.0   4160.0         3      1.0      1.0      yes
# 6             7   66000.0   3880.0         3      2.0      2.0      yes
# 7             8   69000.0   4160.0         3      1.0      3.0      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0   4800.0         3      2.0      4.0      yes
# 542         543   94000.0   6000.0         3      2.0      4.0      yes
# 543         544  103000.0   6000.0         3      2.0      4.0      yes
# 544         545  105000.0   6000.0         3      2.0      2.0      yes
# 545         546  105000.0   6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       9
# bedrooms      0
# bathrms       4
# stories       5
# driveway      0
# recroom       0
# fullbase      0
# gashw         0
# airco         1
# garagepl      0
# prefarea      0
# dtype: int64

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df['lotsize'].fillna('unknown',inplace=True)

# %%
df
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0   5850.0         3      NaN      2.0      yes
# 1             2   38500.0   4000.0         2      1.0      1.0      yes
# 2             3   49500.0   3060.0         3      1.0      1.0      yes
# 3             4   60500.0  unknown         3      1.0      NaN      yes
# 4             5   61000.0   6360.0         2      NaN      1.0      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0   4800.0         3      2.0      4.0      yes
# 542         543   94000.0   6000.0         3      2.0      4.0      yes
# 543         544  103000.0   6000.0         3      2.0      4.0      yes
# 544         545  105000.0   6000.0         3      2.0      2.0      yes
# 545         546  105000.0   6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       9
# bedrooms      0
# bathrms       4
# stories       5
# driveway      0
# recroom       0
# fullbase      0
# gashw         0
# airco         1
# garagepl      0
# prefarea      0
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 1             2   38500.0   4000.0         2      1.0      1.0      yes
# 2             3   49500.0   3060.0         3      1.0      1.0      yes
# 5             6   66000.0   4160.0         3      1.0      1.0      yes
# 6             7   66000.0   3880.0         3      2.0      2.0      yes
# 7             8   69000.0   4160.0         3      1.0      3.0      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0   4800.0         3      2.0      4.0      yes
# 542         543   94000.0   6000.0         3      2.0      4.0      yes
# 543         544  103000.0   6000.0         3      2.0      4.0      yes
# 544         545  105000.0   6000.0         3      2.0      2.0      yes
# 545         546  105000.0   6000.0         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       0
# bedrooms      0
# bathrms       4
# stories       5
# driveway      0
# recroom       0
# fullbase      0
# gashw         0
# airco         1
# garagepl      0
# prefarea      0
# dtype: int64

# %%
sns.boxplot(x='lotsize',data=df)
# Out:
# <AxesSubplot:xlabel='lotsize'>

# %%
import sklearn
from sklearn.datasets import load_boston
q1=np.percentile(df['lotsize'],25,interpolation='midpoint')
q3=np.percentile(df['lotsize'],75,interpolation='midpoint')

iqr=q3-q1
upper =np.where(df['lotsize']>(q3+1.5*iqr))
print(upper)
print(type(upper))
lower =np.where(df['lotsize']<(q1-1.5*iqr))
print(lower)
print(type(lower))
print(df.shape)
df.drop(upper[0],inplace=True)
df.drop(lower[0],inplace=True)
print(df.shape)
# Out:
# (array([111, 308, 318, 319, 322, 335, 339, 342, 364, 381, 393, 436, 478],
#       dtype=int64),)
# <class 'tuple'>
# (array([], dtype=int64),)
# <class 'tuple'>
# (492, 13)
# C:\Users\NAGMA\AppData\Local\Temp\ipykernel_3812\62123129.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['lotsize'],25,interpolation='midpoint')
# C:\Users\NAGMA\AppData\Local\Temp\ipykernel_3812\62123129.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['lotsize'],75,interpolation='midpoint')
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          price       lotsize    bedrooms     bathrms  \
# count  492.000000     492.000000    492.000000  492.000000  492.000000
# mean   273.894309   67688.804878   5080.510163    2.961382    1.294715
# std    160.987713   26796.047314   2137.973287    0.750107    0.511111
# min      2.000000   25000.000000   1650.000000    1.000000    1.000000
# 25%    133.750000   49000.000000   3520.000000    2.000000    1.000000
# 50%    267.500000   61600.000000   4500.000000    3.000000    1.000000
# 75%    421.250000   80187.500000   6305.250000    3.000000    2.000000
# max    546.000000  190000.000000  16200.000000    6.000000    4.000000
#
#           stories    garagepl
# count  492.000000  492.000000
# mean     1.808943    0.666667
# std      0.856318    0.848304
# min      1.000000    0.000000
# 25%      1.000000    0.000000
# 50%      2.000000    0.000000
# 75%      2.000000    1.000000
# max      4.000000    3.000000

# %%
sns.boxplot(x='lotsize',data=df)
# Out:
# <AxesSubplot:xlabel='lotsize'>
